# %% [markdown]
# # zib gereed maken voor mapping
#
# * inlezen en layout consistent maken met XtEHR
# * opslaan voor mapping - zie mapping Notebook
#
# ## imports

# %%
import pandas as pd
import os

# %% [markdown]
# ## toon de zibs in folder (hier: zib2024)

# %%
base = 'zibs2024'
folder = os.path.join(base, 'downloads')
files = os.listdir(folder)
files
# Out:
# ['Condition-v1.1(2024EN).xlsx',
#  'MedicalDevice-v5.0(2024EN).xlsx',
#  'Patient-v4.3(2024EN).xlsx',
#  'Procedure-v6.0(2024EN).xlsx']

# %% [markdown]
# ## kies een zib

# %%
file = files[2]
print(file)
url = os.path.join(folder, file)
zibdf = pd.read_excel(url, sheet_name='Information Model', header=0)
zibdf
# Out:
# Patient-v4.3(2024EN).xlsx
#    Type            Id  Concept                    Concept_1  \
# 0   NaN   NL-CM:0.1.1  Patient                      Patient
# 1   NaN   NL-CM:0.1.6      NaN              NameInformation
# 2   NaN   NL-CM:0.1.4      NaN           AddressInformation
# 3   NaN   NL-CM:0.1.5      NaN           ContactInformation
# 4    II   NL-CM:0.1.7      NaN  PatientIdentificationNumber
# 5    TS  NL-CM:0.1.10      NaN                  DateOfBirth
# 6    CD   NL-CM:0.1.9      NaN                       Gender
# 7    CD  NL-CM:0.1.34      NaN               GenderIdentity
# 8    BL  NL-CM:0.1.31      NaN       MultipleBirthIndicator
# 9   INT  NL-CM:0.1.35      NaN        MultipleBirthSequence
# 10   BL  NL-CM:0.1.32      NaN               DeathIndicator
# 11   TS  NL-CM:0.1.33      NaN                  DateOfDeath
#
#                       Concept_2                    Concept_3  \
# 0                       Patient                      Patient
# 1               NameInformation              NameInformation
# 2            AddressInformation           AddressInformation
# 3            ContactInformation           ContactInformation
# 4   PatientIdentificationNumber  PatientIdentificationNumber
# 5                   DateOfBirth                  DateOfBirth
# 6                        Gender                       Gender
# 7                GenderIdentity               GenderIdentity
# 8        MultipleBirthIndicator       MultipleBirthIndicator
# 9         MultipleBirthSequence        MultipleBirthSequence
# 10               DeathIndicator               DeathIndicator
# 11                  DateOfDeath                  DateOfDeath
#
#                       Concept_4                    Concept_5 Card.  \
# 0                       Patient                      Patient   NaN
# 1               NameInformation              NameInformation     1
# 2            AddressInformation           AddressInformation  0..*
# 3            ContactInformation           ContactInformation  0..1
# 4   PatientIdentificationNumber  PatientIdentificationNumber  0..*
# 5                   DateOfBirth                  DateOfBirth     1
# 6                        Gender                       Gender     1
# 7                GenderIdentity               GenderIdentity  0..1
# 8        MultipleBirthIndicator       MultipleBirthIndicator     1
# 9         MultipleBirthSequence        MultipleBirthSequence  0..1
# 10               DeathIndicator               DeathIndicator     1
# 11                  DateOfDeath                  DateOfDeath  0..1
#
#                                            Definition  \
# 0   Root concept of the Patient information model....
# 1                                Patient's full name.
# 2                      Patient's address information.
# 3   Patient’s telephone number(s) or e-mail addres...
# 4   The patient’s identification number. In transf...
# 5   Patient’s date of birth. The date of birth is ...
# 6                    Patient’s administrative gender.
# 7        The gender with which the person identifies.
# 8   An indication stating whether the patient is o...
# 9   The birth number in the sequence of a multiple...
# 10  An indication stating whether the patient has ...
# 11  The date on which the patient died. A ‘vague’ ...
#
#                     DefinitionCode               Reference
# 0                116154003 Patient                     NaN
# 1                              NaN         NameInformation
# 2                              NaN      AddressInformation
# 3                              NaN      ContactInformation
# 4                              NaN     Burgerservicenummer
# 5               21112-8 Birth date                     NaN
# 6                      46098-0 Sex          GenderCodelist
# 7   33821000087103 Gender identity  GenderIdentityCodelist
# 8                              NaN                     NaN
# 9                              NaN                     NaN
# 10                  419099009 Dead                     NaN
# 11    81954-0 Date of death [Date]                     NaN

# %% [markdown]
# ## opschonen zib
#
# * lowercase kolomnamen
# * paar labels laten vervallen
# * name en path kolom toevoegen
# * name vullen (naam attribuut)
# * kolommen opschonen tot benodigde
#
# Handmatig:
# * path vullen (als in logical model, dus pad.pad2.pad3.naam etc.)

# %%
zibdf.columns = [col.lower() for col in zibdf.columns]
# zibdf = zibdf.drop(labels=['unnamed: 0', 'reference'], axis=1).dropna(how='all')
zibdf.insert(0, 'name', None)
zibdf.insert(0, 'path', None)
zibdf.fillna('')
zibdf
# Out:
#     path  name type            id  concept                    concept_1  \
# 0   None  None  NaN   NL-CM:0.1.1  Patient                      Patient
# 1   None  None  NaN   NL-CM:0.1.6      NaN              NameInformation
# 2   None  None  NaN   NL-CM:0.1.4      NaN           AddressInformation
# 3   None  None  NaN   NL-CM:0.1.5      NaN           ContactInformation
# 4   None  None   II   NL-CM:0.1.7      NaN  PatientIdentificationNumber
# 5   None  None   TS  NL-CM:0.1.10      NaN                  DateOfBirth
# 6   None  None   CD   NL-CM:0.1.9      NaN                       Gender
# 7   None  None   CD  NL-CM:0.1.34      NaN               GenderIdentity
# 8   None  None   BL  NL-CM:0.1.31      NaN       MultipleBirthIndicator
# 9   None  None  INT  NL-CM:0.1.35      NaN        MultipleBirthSequence
# 10  None  None   BL  NL-CM:0.1.32      NaN               DeathIndicator
# 11  None  None   TS  NL-CM:0.1.33      NaN                  DateOfDeath
#
#                       concept_2                    concept_3  \
# 0                       Patient                      Patient
# 1               NameInformation              NameInformation
# 2            AddressInformation           AddressInformation
# 3            ContactInformation           ContactInformation
# 4   PatientIdentificationNumber  PatientIdentificationNumber
# 5                   DateOfBirth                  DateOfBirth
# 6                        Gender                       Gender
# 7                GenderIdentity               GenderIdentity
# 8        MultipleBirthIndicator       MultipleBirthIndicator
# 9         MultipleBirthSequence        MultipleBirthSequence
# 10               DeathIndicator               DeathIndicator
# 11                  DateOfDeath                  DateOfDeath
#
#                       concept_4                    concept_5 card.  \
# 0                       Patient                      Patient   NaN
# 1               NameInformation              NameInformation     1
# 2            AddressInformation           AddressInformation  0..*
# 3            ContactInformation           ContactInformation  0..1
# 4   PatientIdentificationNumber  PatientIdentificationNumber  0..*
# 5                   DateOfBirth                  DateOfBirth     1
# 6                        Gender                       Gender     1
# 7                GenderIdentity               GenderIdentity  0..1
# 8        MultipleBirthIndicator       MultipleBirthIndicator     1
# 9         MultipleBirthSequence        MultipleBirthSequence  0..1
# 10               DeathIndicator               DeathIndicator     1
# 11                  DateOfDeath                  DateOfDeath  0..1
#
#                                            definition  \
# 0   Root concept of the Patient information model....
# 1                                Patient's full name.
# 2                      Patient's address information.
# 3   Patient’s telephone number(s) or e-mail addres...
# 4   The patient’s identification number. In transf...
# 5   Patient’s date of birth. The date of birth is ...
# 6                    Patient’s administrative gender.
# 7        The gender with which the person identifies.
# 8   An indication stating whether the patient is o...
# 9   The birth number in the sequence of a multiple...
# 10  An indication stating whether the patient has ...
# 11  The date on which the patient died. A ‘vague’ ...
#
#                     definitioncode               reference
# 0                116154003 Patient                     NaN
# 1                              NaN         NameInformation
# 2                              NaN      AddressInformation
# 3                              NaN      ContactInformation
# 4                              NaN     Burgerservicenummer
# 5               21112-8 Birth date                     NaN
# 6                      46098-0 Sex          GenderCodelist
# 7   33821000087103 Gender identity  GenderIdentityCodelist
# 8                              NaN                     NaN
# 9                              NaN                     NaN
# 10                  419099009 Dead                     NaN
# 11    81954-0 Date of death [Date]                     NaN

# %% [markdown]
# ## Vullen name, path

# %%
concepts = []
for i, row in zibdf.iterrows():
    if pd.notna(row['concept']):
        concepts.append(row['concept'])
    for j, conceptname in enumerate(['concept_1', 'concept_2', 'concept_3', 'concept_4', 'concept_5']):
        # print(j, conceptname, row[conceptname], concepts[-1])
        if pd.notna(row[conceptname]) and concepts[-1] != row[conceptname]:
            try:
                concepts[j + 1] = row[conceptname]
            except IndexError: 
                concepts.append(row[conceptname])
            if len(concepts) > j + 2:
                concepts.pop()
    print(i, '.'.join( concepts))
    zibdf.at[i, 'path'] = '.'.join(concepts)
    zibdf.at[i, 'name'] = concepts[-1]
zibdf = zibdf[['name', 'path', 'type', 'card.', 'id', 'definition', 'definitioncode']].fillna('')
zibdf
# Out:
# 0 Patient
# 1 Patient.NameInformation
# 2 Patient.AddressInformation
# 3 Patient.ContactInformation
# 4 Patient.PatientIdentificationNumber
# 5 Patient.DateOfBirth
# 6 Patient.Gender
# 7 Patient.GenderIdentity
# 8 Patient.MultipleBirthIndicator
# 9 Patient.MultipleBirthSequence
# 10 Patient.DeathIndicator
# 11 Patient.DateOfDeath
#                            name                                 path type  \
# 0                       Patient                              Patient
# 1               NameInformation              Patient.NameInformation
# 2            AddressInformation           Patient.AddressInformation
# 3            ContactInformation           Patient.ContactInformation
# 4   PatientIdentificationNumber  Patient.PatientIdentificationNumber   II
# 5                   DateOfBirth                  Patient.DateOfBirth   TS
# 6                        Gender                       Patient.Gender   CD
# 7                GenderIdentity               Patient.GenderIdentity   CD
# 8        MultipleBirthIndicator       Patient.MultipleBirthIndicator   BL
# 9         MultipleBirthSequence        Patient.MultipleBirthSequence  INT
# 10               DeathIndicator               Patient.DeathIndicator   BL
# 11                  DateOfDeath                  Patient.DateOfDeath   TS
#
#    card.            id                                         definition  \
# 0          NL-CM:0.1.1  Root concept of the Patient information model....
# 1      1   NL-CM:0.1.6                               Patient's full name.
# 2   0..*   NL-CM:0.1.4                     Patient's address information.
# 3   0..1   NL-CM:0.1.5  Patient’s telephone number(s) or e-mail addres...
# 4   0..*   NL-CM:0.1.7  The patient’s identification number. In transf...
# 5      1  NL-CM:0.1.10  Patient’s date of birth. The date of birth is ...
# 6      1   NL-CM:0.1.9                   Patient’s administrative gender.
# 7   0..1  NL-CM:0.1.34       The gender with which the person identifies.
# 8      1  NL-CM:0.1.31  An indication stating whether the patient is o...
# 9   0..1  NL-CM:0.1.35  The birth number in the sequence of a multiple...
# 10     1  NL-CM:0.1.32  An indication stating whether the patient has ...
# 11  0..1  NL-CM:0.1.33  The date on which the patient died. A ‘vague’ ...
#
#                     definitioncode
# 0                116154003 Patient
# 1
# 2
# 3
# 4
# 5               21112-8 Birth date
# 6                      46098-0 Sex
# 7   33821000087103 Gender identity
# 8
# 9
# 10                  419099009 Dead
# 11    81954-0 Date of death [Date]

# %% [markdown]
# ## Excel opslaan

# %%
url = os.path.join(base, 'mappable', file)
zibdf.to_excel(url, index=False)
