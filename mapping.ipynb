# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
zibs
# Out:
# ['MedicalDevice-v5.0(2024EN).xlsx',
#  'Patient-v4.3(2024EN).xlsx',
#  'Procedure-v6.0(2024EN).xlsx']

# %%
zib = zibs[0]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
# MedicalDevice-v5.0(2024EN).xlsx
#                             name                                        path  \
# 0                  MedicalDevice                               MedicalDevice
# 1          Indication::Diagnosis         MedicalDevice.Indication::Diagnosis
# 2   Location::HealthcareProvider  MedicalDevice.Location::HealthcareProvider
# 3             HealthProfessional            MedicalDevice.HealthProfessional
# 4                        Product                       MedicalDevice.Product
# 5                    ProductType           MedicalDevice.Product.ProductType
# 6                      ProductID             MedicalDevice.Product.ProductID
# 7             ProductDescription            MedicalDevice.ProductDescription
# 8             AnatomicalLocation            MedicalDevice.AnatomicalLocation
# 9                      StartDate                     MedicalDevice.StartDate
# 10                       EndDate                       MedicalDevice.EndDate
# 11                       Comment                       MedicalDevice.Comment
#
#    type card.             id  \
# 0   NaN   NaN   NL-CM:10.1.1
# 1   NaN  0..*  NL-CM:10.1.17
# 2   NaN  0..1   NL-CM:10.1.8
# 3   NaN  0..1   NL-CM:10.1.9
# 4   NaN     1   NL-CM:10.1.2
# 5    CD  0..1   NL-CM:10.1.3
# 6    ST  0..1  NL-CM:10.1.16
# 7    ST  0..1  NL-CM:10.1.13
# 8   NaN  0..1  NL-CM:10.1.15
# 9    TS  0..1  NL-CM:10.1.11
# 10   TS  0..1  NL-CM:10.1.14
# 11   ST  0..1  NL-CM:10.1.10
#
#                                            definition  \
# 0   Root concept of the MedicalDevice information ...
# 1   The diagnosis as indication for the medical de...
# 2   The healthcare provider where use of the medic...
# 3   The health professional involved in the indica...
# 4      The medical device (internally or externally).
# 5                    The code of the type of product.
# 6   Globally unique identification of the product,...
# 7                 Textual description of the product.
# 8   Patient’s anatomical location of the medical d...
# 9   The start date of the first use or implant of ...
# 10  The end date of the last use or explant of the...
# 11  Comment about use or information on the medica...
#
#                                        definitioncode
# 0                                     49062001 Device
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                          405815000 Procedure device
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                              363698007 Finding site
# 9                                                 NaN
# 10                                                NaN
# 11  48767-8 Annotation comment [Interpretation] Na...

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
xlms
# Out:
# ['Condition.xlsx',
#  'Device.xlsx',
#  'DeviceUse.xlsx',
#  'Patient.xlsx',
#  'Procedure.xlsx']

# %%
xlm = xlms[1]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use
# xlm = xlms[2]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# Device.xlsx
# DeviceUse.xlsx
#                             id                        path  \
# 0                   EHDSDevice                  EHDSDevice
# 1        EHDSDevice.identifier       EHDSDevice.identifier
# 2      EHDSDevice.manufacturer     EHDSDevice.manufacturer
# 3   EHDSDevice.manufactureDate  EHDSDevice.manufactureDate
# 4        EHDSDevice.expiryDate       EHDSDevice.expiryDate
# 5         EHDSDevice.lotNumber        EHDSDevice.lotNumber
# 6      EHDSDevice.serialNumber     EHDSDevice.serialNumber
# 7              EHDSDevice.name             EHDSDevice.name
# 8       EHDSDevice.modelNumber      EHDSDevice.modelNumber
# 9           EHDSDevice.version          EHDSDevice.version
# 10             EHDSDevice.type             EHDSDevice.type
# 11             EHDSDevice.note             EHDSDevice.note
# 12               EHDSDeviceUse               EHDSDeviceUse
# 13    EHDSDeviceUse.identifier    EHDSDeviceUse.identifier
# 14        EHDSDeviceUse.status        EHDSDeviceUse.status
# 15   EHDSDeviceUse.implantDate   EHDSDeviceUse.implantDate
# 16       EHDSDeviceUse.endDate       EHDSDeviceUse.endDate
# 17        EHDSDeviceUse.device        EHDSDeviceUse.device
# 18       EHDSDeviceUse.subject       EHDSDeviceUse.subject
# 19      EHDSDeviceUse.bodySite      EHDSDeviceUse.bodySite
# 20          EHDSDeviceUse.note          EHDSDeviceUse.note
# 21      EHDSDeviceUse.recorded      EHDSDeviceUse.recorded
# 22        EHDSDeviceUse.source        EHDSDeviceUse.source
#
#                         short  \
# 0                Device model
# 1         C.12.1 - Identifier
# 2       C.12.2 - Manufacturer
# 3   C.12.3 - Manufacture date
# 4        C.12.4 - Expiry date
# 5         C.12.5 - Lot number
# 6      C.12.6 - Serial number
# 7               C.12.7 - Name
# 8       C.12.8 - Model number
# 9            C.12.9 - Version
# 10             C.12.10 - Type
# 11             C.12.11 - Note
# 12           Device use model
# 13        C.25.1 - Identifier
# 14            C.25.2 - Status
# 15      C.25.3 - Implant date
# 16          C.25.4 - End date
# 17            C.25.5 - Device
# 18           C.25.6 - Subject
# 19         C.25.7 - Body site
# 20              C.25.8 - Note
# 21          C.25.9 - Recorded
# 22           C.25.10 - Source
#
#                                            definition             type card.  \
# 0   C.12 - EHDS refined base model for Device info...              NaN  0..*
# 1   An identifier of the device which is unique wi...       Identifier  1..*
# 2                         Name of device manufacturer           string  0..1
# 3   The date and time when the device was manufact...         dateTime  0..1
# 4   The date and time beyond which this device is ...         dateTime  0..1
# 5                           Lot number of manufacture           string  0..1
# 6          Serial number assigned by the manufacturer           string  0..1
# 7   The name and name type of the device as known ...           string  0..*
# 8      The manufacturer's model number for the device           string  0..1
# 9   The actual design of the device or software ve...           string  0..1
# 10                                        Device type  CodeableConcept  0..*
# 11                          Device notes and comments        Narrative  0..*
# 12      C.25 - EHDS refined base model for Device Use              NaN  0..*
# 13                  An identifier for this statement.       Identifier  0..*
# 14                Current status of the Device Usage.  CodeableConcept  0..1
# 15                 Date when procedure was performed.         dateTime  0..1
# 16  Date when the device was explanted from the pa...         dateTime  0..1
# 17                    The details of the device used.        Reference  1..1
# 18                      The patient using the device.        Reference  1..1
# 19  Anatomical location of the device. May include...  CodeableConcept  0..1
# 20  Details about the device statement that were n...        Narrative  0..*
# 21  Date and time at which the statement was made/...         dateTime  0..1
# 22  Who reported the device was being used by the ...        Reference  0..1
#
#                                               binding
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'strength': 'preferred', 'description': 'SNOM...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'strength': 'preferred', 'description': 'HL7 ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
maps
# Out:
# ['Condition.xlsx',
#  'Device-and-DeviceUse.xlsx',
#  'Device.xlsx',
#  'DeviceUse.xlsx',
#  'Patient.xlsx',
#  'Procedure.xlsx',
#  'xtehr2zibs',
#  'xtehr2zibs2024']

# %%
file = maps[1]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# Device-and-DeviceUse.xlsx
# maps\Device-and-DeviceUse.xlsx
#                          xtehr                                         zib
# 0                   EHDSDevice                       MedicalDevice.Product
# 1        EHDSDevice.identifier             MedicalDevice.Product.ProductID
# 2      EHDSDevice.manufacturer                                         NaN
# 3   EHDSDevice.manufactureDate                                         NaN
# 4        EHDSDevice.expiryDate                                         NaN
# 5         EHDSDevice.lotNumber                                         NaN
# 6      EHDSDevice.serialNumber                                         NaN
# 7              EHDSDevice.name                                         NaN
# 8       EHDSDevice.modelNumber           MedicalDevice.Product.ProductType
# 9           EHDSDevice.version                                         NaN
# 10             EHDSDevice.type                                         NaN
# 11             EHDSDevice.note                                         NaN
# 12               EHDSDeviceUse                               MedicalDevice
# 13    EHDSDeviceUse.identifier                                         NaN
# 14        EHDSDeviceUse.status                                         NaN
# 15   EHDSDeviceUse.implantDate                     MedicalDevice.StartDate
# 16       EHDSDeviceUse.endDate                       MedicalDevice.EndDate
# 17        EHDSDeviceUse.device                                         NaN
# 18       EHDSDeviceUse.subject                                         NaN
# 19      EHDSDeviceUse.bodySite            MedicalDevice.AnatomicalLocation
# 20          EHDSDeviceUse.note                       MedicalDevice.Comment
# 21      EHDSDeviceUse.recorded                                         NaN
# 22        EHDSDeviceUse.source                                         NaN
# 23                         NaN            MedicalDevice.ProductDescription
# 24                         NaN           MedicalDevice.Indication::Problem
# 25                         NaN  MedicalDevice.Location::HealthcareProvider
# 26                         NaN            MedicalDevice.HealthProfessional
# 27                         NaN         MedicalDevice.Indication::Diagnosis

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                          xtehr                                         zib  \
# 0                   EHDSDevice                       MedicalDevice.Product
# 1        EHDSDevice.expiryDate                                         NaN
# 2        EHDSDevice.identifier             MedicalDevice.Product.ProductID
# 3         EHDSDevice.lotNumber                                         NaN
# 4   EHDSDevice.manufactureDate                                         NaN
# 5      EHDSDevice.manufacturer                                         NaN
# 6       EHDSDevice.modelNumber           MedicalDevice.Product.ProductType
# 7              EHDSDevice.name                                         NaN
# 8              EHDSDevice.note                                         NaN
# 9      EHDSDevice.serialNumber                                         NaN
# 10             EHDSDevice.type                                         NaN
# 11          EHDSDevice.version                                         NaN
# 12               EHDSDeviceUse                               MedicalDevice
# 13      EHDSDeviceUse.bodySite            MedicalDevice.AnatomicalLocation
# 14        EHDSDeviceUse.device                                         NaN
# 15       EHDSDeviceUse.endDate                       MedicalDevice.EndDate
# 16    EHDSDeviceUse.identifier                                         NaN
# 17   EHDSDeviceUse.implantDate                     MedicalDevice.StartDate
# 18          EHDSDeviceUse.note                       MedicalDevice.Comment
# 19      EHDSDeviceUse.recorded                                         NaN
# 20        EHDSDeviceUse.source                                         NaN
# 21        EHDSDeviceUse.status                                         NaN
# 22       EHDSDeviceUse.subject                                         NaN
# 23                         NaN            MedicalDevice.HealthProfessional
# 24                         NaN         MedicalDevice.Indication::Diagnosis
# 25                         NaN           MedicalDevice.Indication::Problem
# 26                         NaN  MedicalDevice.Location::HealthcareProvider
# 27                         NaN            MedicalDevice.ProductDescription
#
#                         name_zib                                    path_zib  \
# 0                        Product                       MedicalDevice.Product
# 1                            NaN                                         NaN
# 2                      ProductID             MedicalDevice.Product.ProductID
# 3                            NaN                                         NaN
# 4                            NaN                                         NaN
# 5                            NaN                                         NaN
# 6                    ProductType           MedicalDevice.Product.ProductType
# 7                            NaN                                         NaN
# 8                            NaN                                         NaN
# 9                            NaN                                         NaN
# 10                           NaN                                         NaN
# 11                           NaN                                         NaN
# 12                 MedicalDevice                               MedicalDevice
# 13            AnatomicalLocation            MedicalDevice.AnatomicalLocation
# 14                           NaN                                         NaN
# 15                       EndDate                       MedicalDevice.EndDate
# 16                           NaN                                         NaN
# 17                     StartDate                     MedicalDevice.StartDate
# 18                       Comment                       MedicalDevice.Comment
# 19                           NaN                                         NaN
# 20                           NaN                                         NaN
# 21                           NaN                                         NaN
# 22                           NaN                                         NaN
# 23            HealthProfessional            MedicalDevice.HealthProfessional
# 24         Indication::Diagnosis         MedicalDevice.Indication::Diagnosis
# 25                           NaN                                         NaN
# 26  Location::HealthcareProvider  MedicalDevice.Location::HealthcareProvider
# 27            ProductDescription            MedicalDevice.ProductDescription
#
#    type_zib card._zib         id_zib  \
# 0       NaN         1   NL-CM:10.1.2
# 1       NaN       NaN            NaN
# 2        ST      0..1  NL-CM:10.1.16
# 3       NaN       NaN            NaN
# 4       NaN       NaN            NaN
# 5       NaN       NaN            NaN
# 6        CD      0..1   NL-CM:10.1.3
# 7       NaN       NaN            NaN
# 8       NaN       NaN            NaN
# 9       NaN       NaN            NaN
# 10      NaN       NaN            NaN
# 11      NaN       NaN            NaN
# 12      NaN       NaN   NL-CM:10.1.1
# 13      NaN      0..1  NL-CM:10.1.15
# 14      NaN       NaN            NaN
# 15       TS      0..1  NL-CM:10.1.14
# 16      NaN       NaN            NaN
# 17       TS      0..1  NL-CM:10.1.11
# 18       ST      0..1  NL-CM:10.1.10
# 19      NaN       NaN            NaN
# 20      NaN       NaN            NaN
# 21      NaN       NaN            NaN
# 22      NaN       NaN            NaN
# 23      NaN      0..1   NL-CM:10.1.9
# 24      NaN      0..*  NL-CM:10.1.17
# 25      NaN       NaN            NaN
# 26      NaN      0..1   NL-CM:10.1.8
# 27       ST      0..1  NL-CM:10.1.13
#
#                                        definition_zib  \
# 0      The medical device (internally or externally).
# 1                                                 NaN
# 2   Globally unique identification of the product,...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                    The code of the type of product.
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Root concept of the MedicalDevice information ...
# 13  Patient’s anatomical location of the medical d...
# 14                                                NaN
# 15  The end date of the last use or explant of the...
# 16                                                NaN
# 17  The start date of the first use or implant of ...
# 18  Comment about use or information on the medica...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  The health professional involved in the indica...
# 24  The diagnosis as indication for the medical de...
# 25                                                NaN
# 26  The healthcare provider where use of the medic...
# 27                Textual description of the product.
#
#                                    definitioncode_zib  \
# 0                          405815000 Procedure device
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                    49062001 Device
# 13                             363698007 Finding site
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  48767-8 Annotation comment [Interpretation] Na...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#                       id_xtehr                  path_xtehr  \
# 0                   EHDSDevice                  EHDSDevice
# 1        EHDSDevice.expiryDate       EHDSDevice.expiryDate
# 2        EHDSDevice.identifier       EHDSDevice.identifier
# 3         EHDSDevice.lotNumber        EHDSDevice.lotNumber
# 4   EHDSDevice.manufactureDate  EHDSDevice.manufactureDate
# 5      EHDSDevice.manufacturer     EHDSDevice.manufacturer
# 6       EHDSDevice.modelNumber      EHDSDevice.modelNumber
# 7              EHDSDevice.name             EHDSDevice.name
# 8              EHDSDevice.note             EHDSDevice.note
# 9      EHDSDevice.serialNumber     EHDSDevice.serialNumber
# 10             EHDSDevice.type             EHDSDevice.type
# 11          EHDSDevice.version          EHDSDevice.version
# 12               EHDSDeviceUse               EHDSDeviceUse
# 13      EHDSDeviceUse.bodySite      EHDSDeviceUse.bodySite
# 14        EHDSDeviceUse.device        EHDSDeviceUse.device
# 15       EHDSDeviceUse.endDate       EHDSDeviceUse.endDate
# 16    EHDSDeviceUse.identifier    EHDSDeviceUse.identifier
# 17   EHDSDeviceUse.implantDate   EHDSDeviceUse.implantDate
# 18          EHDSDeviceUse.note          EHDSDeviceUse.note
# 19      EHDSDeviceUse.recorded      EHDSDeviceUse.recorded
# 20        EHDSDeviceUse.source        EHDSDeviceUse.source
# 21        EHDSDeviceUse.status        EHDSDeviceUse.status
# 22       EHDSDeviceUse.subject       EHDSDeviceUse.subject
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                         NaN                         NaN
# 26                         NaN                         NaN
# 27                         NaN                         NaN
#
#                   short_xtehr  \
# 0                Device model
# 1        C.12.4 - Expiry date
# 2         C.12.1 - Identifier
# 3         C.12.5 - Lot number
# 4   C.12.3 - Manufacture date
# 5       C.12.2 - Manufacturer
# 6       C.12.8 - Model number
# 7               C.12.7 - Name
# 8              C.12.11 - Note
# 9      C.12.6 - Serial number
# 10             C.12.10 - Type
# 11           C.12.9 - Version
# 12           Device use model
# 13         C.25.7 - Body site
# 14            C.25.5 - Device
# 15          C.25.4 - End date
# 16        C.25.1 - Identifier
# 17      C.25.3 - Implant date
# 18              C.25.8 - Note
# 19          C.25.9 - Recorded
# 20           C.25.10 - Source
# 21            C.25.2 - Status
# 22           C.25.6 - Subject
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
#
#                                      definition_xtehr       type_xtehr  \
# 0   C.12 - EHDS refined base model for Device info...              NaN
# 1   The date and time beyond which this device is ...         dateTime
# 2   An identifier of the device which is unique wi...       Identifier
# 3                           Lot number of manufacture           string
# 4   The date and time when the device was manufact...         dateTime
# 5                         Name of device manufacturer           string
# 6      The manufacturer's model number for the device           string
# 7   The name and name type of the device as known ...           string
# 8                           Device notes and comments        Narrative
# 9          Serial number assigned by the manufacturer           string
# 10                                        Device type  CodeableConcept
# 11  The actual design of the device or software ve...           string
# 12      C.25 - EHDS refined base model for Device Use              NaN
# 13  Anatomical location of the device. May include...  CodeableConcept
# 14                    The details of the device used.        Reference
# 15  Date when the device was explanted from the pa...         dateTime
# 16                  An identifier for this statement.       Identifier
# 17                 Date when procedure was performed.         dateTime
# 18  Details about the device statement that were n...        Narrative
# 19  Date and time at which the statement was made/...         dateTime
# 20  Who reported the device was being used by the ...        Reference
# 21                Current status of the Device Usage.  CodeableConcept
# 22                      The patient using the device.        Reference
# 23                                                NaN              NaN
# 24                                                NaN              NaN
# 25                                                NaN              NaN
# 26                                                NaN              NaN
# 27                                                NaN              NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..1                                                NaN
# 2         1..*                                                NaN
# 3         0..1                                                NaN
# 4         0..1                                                NaN
# 5         0..1                                                NaN
# 6         0..1                                                NaN
# 7         0..*                                                NaN
# 8         0..*                                                NaN
# 9         0..1                                                NaN
# 10        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 11        0..1                                                NaN
# 12        0..*                                                NaN
# 13        0..1                                                NaN
# 14        1..1                                                NaN
# 15        0..1                                                NaN
# 16        0..*                                                NaN
# 17        0..1                                                NaN
# 18        0..*                                                NaN
# 19        0..1                                                NaN
# 20        0..1                                                NaN
# 21        0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 22        1..1                                                NaN
# 23         NaN                                                NaN
# 24         NaN                                                NaN
# 25         NaN                                                NaN
# 26         NaN                                                NaN
# 27         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                            zib                       xtehr  \
# 0                        MedicalDevice.Product                  EHDSDevice
# 1                                          NaN       EHDSDevice.expiryDate
# 2              MedicalDevice.Product.ProductID       EHDSDevice.identifier
# 3                                          NaN        EHDSDevice.lotNumber
# 4                                          NaN  EHDSDevice.manufactureDate
# 5                                          NaN     EHDSDevice.manufacturer
# 6            MedicalDevice.Product.ProductType      EHDSDevice.modelNumber
# 7                                          NaN             EHDSDevice.name
# 8                                          NaN             EHDSDevice.note
# 9                                          NaN     EHDSDevice.serialNumber
# 10                                         NaN             EHDSDevice.type
# 11                                         NaN          EHDSDevice.version
# 12                               MedicalDevice               EHDSDeviceUse
# 13            MedicalDevice.AnatomicalLocation      EHDSDeviceUse.bodySite
# 14                                         NaN        EHDSDeviceUse.device
# 15                       MedicalDevice.EndDate       EHDSDeviceUse.endDate
# 16                                         NaN    EHDSDeviceUse.identifier
# 17                     MedicalDevice.StartDate   EHDSDeviceUse.implantDate
# 18                       MedicalDevice.Comment          EHDSDeviceUse.note
# 19                                         NaN      EHDSDeviceUse.recorded
# 20                                         NaN        EHDSDeviceUse.source
# 21                                         NaN        EHDSDeviceUse.status
# 22                                         NaN       EHDSDeviceUse.subject
# 23            MedicalDevice.HealthProfessional                         NaN
# 24         MedicalDevice.Indication::Diagnosis                         NaN
# 25           MedicalDevice.Indication::Problem                         NaN
# 26  MedicalDevice.Location::HealthcareProvider                         NaN
# 27            MedicalDevice.ProductDescription                         NaN
#
#    type_zib       type_xtehr card._zib card._xtehr
# 0       NaN              NaN         1        0..*
# 1       NaN         dateTime       NaN        0..1
# 2        ST       Identifier      0..1        1..*
# 3       NaN           string       NaN        0..1
# 4       NaN         dateTime       NaN        0..1
# 5       NaN           string       NaN        0..1
# 6        CD           string      0..1        0..1
# 7       NaN           string       NaN        0..*
# 8       NaN        Narrative       NaN        0..*
# 9       NaN           string       NaN        0..1
# 10      NaN  CodeableConcept       NaN        0..*
# 11      NaN           string       NaN        0..1
# 12      NaN              NaN       NaN        0..*
# 13      NaN  CodeableConcept      0..1        0..1
# 14      NaN        Reference       NaN        1..1
# 15       TS         dateTime      0..1        0..1
# 16      NaN       Identifier       NaN        0..*
# 17       TS         dateTime      0..1        0..1
# 18       ST        Narrative      0..1        0..*
# 19      NaN         dateTime       NaN        0..1
# 20      NaN        Reference       NaN        0..1
# 21      NaN  CodeableConcept       NaN        0..1
# 22      NaN        Reference       NaN        1..1
# 23      NaN              NaN      0..1         NaN
# 24      NaN              NaN      0..*         NaN
# 25      NaN              NaN       NaN         NaN
# 26      NaN              NaN      0..1         NaN
# 27       ST              NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebriuken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
Markdown(content)
# Out:
# # Device
#
# | zib                                        | xtehr                      | type_zib   | type_xtehr      | card._zib   | card._xtehr   |
# |:-------------------------------------------|:---------------------------|:-----------|:----------------|:------------|:--------------|
# | MedicalDevice.Product                      | EHDSDevice                 |            |                 | 1           | 0..*          |
# |                                            | EHDSDevice.expiryDate      |            | dateTime        |             | 0..1          |
# | MedicalDevice.Product.ProductID            | EHDSDevice.identifier      | ST         | Identifier      | 0..1        | 1..*          |
# |                                            | EHDSDevice.lotNumber       |            | string          |             | 0..1          |
# |                                            | EHDSDevice.manufactureDate |            | dateTime        |             | 0..1          |
# |                                            | EHDSDevice.manufacturer    |            | string          |             | 0..1          |
# | MedicalDevice.Product.ProductType          | EHDSDevice.modelNumber     | CD         | string          | 0..1        | 0..1          |
# |                                            | EHDSDevice.name            |            | string          |             | 0..*          |
# |                                            | EHDSDevice.note            |            | Narrative       |             | 0..*          |
# |                                            | EHDSDevice.serialNumber    |            | string          |             | 0..1          |
# |                                            | EHDSDevice.type            |            | CodeableConcept |             | 0..*          |
# |                                            | EHDSDevice.version         |            | string          |             | 0..1          |
# | MedicalDevice                              | EHDSDeviceUse              |            |                 |             | 0..*          |
# | MedicalDevice.AnatomicalLocation           | EHDSDeviceUse.bodySite     |            | CodeableConcept | 0..1        | 0..1          |
# |                                            | EHDSDeviceUse.device       |            | Reference       |             | 1..1          |
# | MedicalDevice.EndDate                      | EHDSDeviceUse.endDate      | TS         | dateTime        | 0..1        | 0..1          |
# |                                            | EHDSDeviceUse.identifier   |            | Identifier      |             | 0..*          |
# | MedicalDevice.StartDate                    | EHDSDeviceUse.implantDate  | TS         | dateTime        | 0..1        | 0..1          |
# | MedicalDevice.Comment                      | EHDSDeviceUse.note         | ST         | Narrative       | 0..1        | 0..*          |
# |                                            | EHDSDeviceUse.recorded     |            | dateTime        |             | 0..1          |
# |                                            | EHDSDeviceUse.source       |            | Reference       |             | 0..1          |
# |                                            | EHDSDeviceUse.status       |            | CodeableConcept |             | 0..1          |
# |                                            | EHDSDeviceUse.subject      |            | Reference       |             | 1..1          |
# | MedicalDevice.HealthProfessional           |                            |            |                 | 0..1        |               |
# | MedicalDevice.Indication::Diagnosis        |                            |            |                 | 0..*        |               |
# | MedicalDevice.Indication::Problem          |                            |            |                 |             |               |
# | MedicalDevice.Location::HealthcareProvider |                            |            |                 | 0..1        |               |
# | MedicalDevice.ProductDescription           |                            | ST         |                 | 0..1        |               |
#
#
#
# ## EHDSDevice
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice |
# | zib | MedicalDevice.Product |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 1 |
# | definition_xtehr | C.12 - EHDS refined base model for Device information |
# | definition_zib | The medical device (internally or externally). |
# | definitioncode_zib | 405815000 Procedure device |
# | id_xtehr | EHDSDevice |
# | id_zib | NL-CM:10.1.2 |
# | name_zib | Product |
# | path_xtehr | EHDSDevice |
# | path_zib | MedicalDevice.Product |
# | short_xtehr | Device model |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.expiryDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.expiryDate |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The date and time beyond which this device is no longer valid or should not be used (if applicable). |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.expiryDate |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.expiryDate |
# | path_zib |  |
# | short_xtehr | C.12.4 - Expiry date |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.identifier |
# | zib | MedicalDevice.Product.ProductID |
# | binding_xtehr |  |
# | card._xtehr | 1..* |
# | card._zib | 0..1 |
# | definition_xtehr | An identifier of the device which is unique within in a defined scope. Multiple identifiers can be used. |
# | definition_zib | Globally unique identification of the product, for example the serial number or a UDI (unique device identifier). For some products, the law requires the use of a UDI. Commonly used coding systems are HIBC and GS1/GTIN.
# A UDI often contains more information than just an ID, but also, for example, an expiration date. If a UDI is used, the entire code can be included as text in ProductID, so that no important information is lost. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.identifier |
# | id_zib | NL-CM:10.1.16 |
# | name_zib | ProductID |
# | path_xtehr | EHDSDevice.identifier |
# | path_zib | MedicalDevice.Product.ProductID |
# | short_xtehr | C.12.1 - Identifier |
# | type_xtehr | Identifier |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSDevice.lotNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.lotNumber |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Lot number of manufacture |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.lotNumber |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.lotNumber |
# | path_zib |  |
# | short_xtehr | C.12.5 - Lot number |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.manufactureDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.manufactureDate |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The date and time when the device was manufactured |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.manufactureDate |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.manufactureDate |
# | path_zib |  |
# | short_xtehr | C.12.3 - Manufacture date |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.manufacturer
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.manufacturer |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Name of device manufacturer |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.manufacturer |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.manufacturer |
# | path_zib |  |
# | short_xtehr | C.12.2 - Manufacturer |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.modelNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.modelNumber |
# | zib | MedicalDevice.Product.ProductType |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | The manufacturer's model number for the device |
# | definition_zib | The code of the type of product. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.modelNumber |
# | id_zib | NL-CM:10.1.3 |
# | name_zib | ProductType |
# | path_xtehr | EHDSDevice.modelNumber |
# | path_zib | MedicalDevice.Product.ProductType |
# | short_xtehr | C.12.8 - Model number |
# | type_xtehr | string |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDevice.name
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.name |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | The name and name type of the device as known to the manufacturer and/or patient |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.name |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.name |
# | path_zib |  |
# | short_xtehr | C.12.7 - Name |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.note
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.note |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | Device notes and comments |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.note |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.note |
# | path_zib |  |
# | short_xtehr | C.12.11 - Note |
# | type_xtehr | Narrative |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.serialNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.serialNumber |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Serial number assigned by the manufacturer |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.serialNumber |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.serialNumber |
# | path_zib |  |
# | short_xtehr | C.12.6 - Serial number |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.type
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.type |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'SNOMED CT, EMDN'} |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | Device type |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.type |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.type |
# | path_zib |  |
# | short_xtehr | C.12.10 - Type |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.version |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The actual design of the device or software version running on the device |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.version |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.version |
# | path_zib |  |
# | short_xtehr | C.12.9 - Version |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse |
# | zib | MedicalDevice |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | C.25 - EHDS refined base model for Device Use |
# | definition_zib | Root concept of the MedicalDevice information model. This root concept contains all data elements of the MedicalDevice information model. |
# | definitioncode_zib | 49062001 Device |
# | id_xtehr | EHDSDeviceUse |
# | id_zib | NL-CM:10.1.1 |
# | name_zib | MedicalDevice |
# | path_xtehr | EHDSDeviceUse |
# | path_zib | MedicalDevice |
# | short_xtehr | Device use model |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.bodySite
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.bodySite |
# | zib | MedicalDevice.AnatomicalLocation |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Anatomical location of the device. May include laterality. |
# | definition_zib | Patient’s anatomical location of the medical device used. |
# | definitioncode_zib | 363698007 Finding site |
# | id_xtehr | EHDSDeviceUse.bodySite |
# | id_zib | NL-CM:10.1.15 |
# | name_zib | AnatomicalLocation |
# | path_xtehr | EHDSDeviceUse.bodySite |
# | path_zib | MedicalDevice.AnatomicalLocation |
# | short_xtehr | C.25.7 - Body site |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.device
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.device |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | The details of the device used. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.device |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.device |
# | path_zib |  |
# | short_xtehr | C.25.5 - Device |
# | type_xtehr | Reference |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.endDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.endDate |
# | zib | MedicalDevice.EndDate |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Date when the device was explanted from the patient or the external device was no longer in use; likewise when the device is planned to be explanted. |
# | definition_zib | The end date of the last use or explant of the medical device. A ‘vague’ date, such as only the year, is permitted. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.endDate |
# | id_zib | NL-CM:10.1.14 |
# | name_zib | EndDate |
# | path_xtehr | EHDSDeviceUse.endDate |
# | path_zib | MedicalDevice.EndDate |
# | short_xtehr | C.25.4 - End date |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.identifier |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | An identifier for this statement. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.identifier |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.identifier |
# | path_zib |  |
# | short_xtehr | C.25.1 - Identifier |
# | type_xtehr | Identifier |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.implantDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.implantDate |
# | zib | MedicalDevice.StartDate |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Date when procedure was performed. |
# | definition_zib | The start date of the first use or implant of the medical device. A ‘vague’ date, such as only the year, is permitted. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.implantDate |
# | id_zib | NL-CM:10.1.11 |
# | name_zib | StartDate |
# | path_xtehr | EHDSDeviceUse.implantDate |
# | path_zib | MedicalDevice.StartDate |
# | short_xtehr | C.25.3 - Implant date |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.note
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.note |
# | zib | MedicalDevice.Comment |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Details about the device statement that were not represented at all or sufficiently in one of the attributes provided in a class. These may include for example a comment, an instruction, or a note associated with the statement. |
# | definition_zib | Comment about use or information on the medical device used. |
# | definitioncode_zib | 48767-8 Annotation comment [Interpretation] Narrative |
# | id_xtehr | EHDSDeviceUse.note |
# | id_zib | NL-CM:10.1.10 |
# | name_zib | Comment |
# | path_xtehr | EHDSDeviceUse.note |
# | path_zib | MedicalDevice.Comment |
# | short_xtehr | C.25.8 - Note |
# | type_xtehr | Narrative |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.recorded
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.recorded |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Date and time at which the statement was made/recorded. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.recorded |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.recorded |
# | path_zib |  |
# | short_xtehr | C.25.9 - Recorded |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.source
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.source |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Who reported the device was being used by the patient. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.source |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.source |
# | path_zib |  |
# | short_xtehr | C.25.10 - Source |
# | type_xtehr | Reference |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.status |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 device-statement-status'} |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Current status of the Device Usage. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.status |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.status |
# | path_zib |  |
# | short_xtehr | C.25.2 - Status |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.subject |
# | zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | The patient using the device. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.subject |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.subject |
# | path_zib |  |
# | short_xtehr | C.25.6 - Subject |
# | type_xtehr | Reference |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.HealthProfessional
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.HealthProfessional |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | The health professional involved in the indication for use of the medical device implant. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.9 |
# | name_zib | HealthProfessional |
# | path_xtehr |  |
# | path_zib | MedicalDevice.HealthProfessional |
# | short_xtehr |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.Indication::Diagnosis
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.Indication::Diagnosis |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..* |
# | definition_xtehr |  |
# | definition_zib | The diagnosis as indication for the medical device. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.17 |
# | name_zib | Indication::Diagnosis |
# | path_xtehr |  |
# | path_zib | MedicalDevice.Indication::Diagnosis |
# | short_xtehr |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.Indication::Problem
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.Indication::Problem |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib |  |
# | definition_xtehr |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr |  |
# | path_zib |  |
# | short_xtehr |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.Location::HealthcareProvider
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.Location::HealthcareProvider |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | The healthcare provider where use of the medical device was initiated or where the aid was implanted. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.8 |
# | name_zib | Location::HealthcareProvider |
# | path_xtehr |  |
# | path_zib | MedicalDevice.Location::HealthcareProvider |
# | short_xtehr |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.ProductDescription
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.ProductDescription |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | Textual description of the product. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.13 |
# | name_zib | ProductDescription |
# | path_xtehr |  |
# | path_zib | MedicalDevice.ProductDescription |
# | short_xtehr |  |
# | type_xtehr |  |
# | type_zib | ST |
#
# ### Comments
