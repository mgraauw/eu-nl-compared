# %%
import pandas as pd
import os

# %%
zibbase = 'zibs2020'
zibs = os.path.join(zibbase, 'mappable')
os.listdir(zibs)
# Out:
# ['Nl.zorg.Alert-v4.1(2020EN).xlsx',
#  'Nl.zorg.AllergyIntolerance-v3.3(2020EN).xlsx',
#  'Nl.zorg.HealthcareProvider-v3.4(2020EN).xlsx',
#  'Nl.zorg.HealthProfessional-v3.5(2020EN).xlsx',
#  'Nl.zorg.MedicalDevice-v3.3.1(2020EN).xlsx',
#  'Nl.zorg.Patient-v3.2(2020EN).xlsx',
#  'Nl.zorg.Problem-v4.4(2020EN).xlsx',
#  'Nl.zorg.Procedure-v5.2(2020EN).xlsx']

# %%
zib = 'Nl.zorg.Patient-v3.2(2020EN).xlsx'
zibpath = os.path.join(zibs, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
#                           name                                 path  \
# 0                      Patient                              Patient
# 1              NameInformation              Patient.NameInformation
# 2           AddressInformation           Patient.AddressInformation
# 3           ContactInformation           Patient.ContactInformation
# 4  PatientIdentificationNumber  Patient.PatientIdentificationNumber
# 5                  DateOfBirth                  Patient.DateOfBirth
# 6                       Gender                       Patient.Gender
# 7       MultipleBirthIndicator       Patient.MultipleBirthIndicator
# 8               DeathIndicator               Patient.DeathIndicator
# 9                  DateOfDeath                  Patient.DateOfDeath
#
#                       alias type card.      stereotype            id  \
# 0               NL: Patient  NaN   NaN     rootconcept   NL-CM:0.1.1
# 1          NL: Naamgegevens  NaN  0..1  data,reference   NL-CM:0.1.6
# 2         NL: Adresgegevens  NaN  0..*  data,reference   NL-CM:0.1.4
# 3       NL: Contactgegevens  NaN  0..1  data,reference   NL-CM:0.1.5
# 4   NL: Identificatienummer   II  0..*            data   NL-CM:0.1.7
# 5         NL: Geboortedatum   TS  0..1            data  NL-CM:0.1.10
# 6              NL: Geslacht   CD  0..1            data   NL-CM:0.1.9
# 7     NL: MeerlingIndicator   BL  0..1            data  NL-CM:0.1.31
# 8  NL: OverlijdensIndicator   BL  0..1            data  NL-CM:0.1.32
# 9       NL: DatumOverlijden   TS  0..1            data  NL-CM:0.1.33
#
#                                           definition  \
# 0  Root concept of the Patient information model....
# 1                               Patient's full name.
# 2                     Patient's address information.
# 3  Patient’s telephone number(s) or e-mail addres...
# 4  The patient’s identification number. In transf...
# 5  Patient’s date of birth. The date of birth is ...
# 6                   Patient’s administrative gender.
# 7  An indication stating whether the patient is o...
# 8  An indication stating whether the patient has ...
# 9  The date on which the patient died. A ‘vague’ ...
#
#                         definitioncode
# 0         SNOMED CT: 116154003 Patient
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5            LOINC: 21112-8 Birth date
# 6                   LOINC: 46098-0 Sex
# 7                                  NaN
# 8    SNOMED CT: 397709008 Patient died
# 9  LOINC: 81954-0 Date of death [Date]

# %%
xlmbase = 'xtehr'
xlms = os.path.join(xlmbase, 'mappable')
os.listdir(xlms)
# Out:
# ['Patient.xlsx', 'Procedure.xlsx']

# %%
xlm = 'Patient.xlsx'
xlmpath = os.path.join(xlms, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# Out:
#                                   id                               path  \
# 0                        EHDSPatient                        EHDSPatient
# 1     EHDSPatient.personalIdentifier     EHDSPatient.personalIdentifier
# 2                   EHDSPatient.name                   EHDSPatient.name
# 3            EHDSPatient.dateOfBirth            EHDSPatient.dateOfBirth
# 4   EHDSPatient.administrativeGender   EHDSPatient.administrativeGender
# 5                EHDSPatient.address                EHDSPatient.address
# 6                EHDSPatient.telecom                EHDSPatient.telecom
# 7          EHDSPatient.maritalStatus          EHDSPatient.maritalStatus
# 8            EHDSPatient.citizenship            EHDSPatient.citizenship
# 9  EHDSPatient.communicationLanguage  EHDSPatient.communicationLanguage
#
#                                short  \
# 0                      Patient model
# 1        C.1.1 - Personal identifier
# 2                       C.1.2 - Name
# 3              C.1.3 - Date of birth
# 4      C.1.4 - Administrative gender
# 5                    C.1.5 - Address
# 6                    C.1.6 - Telecom
# 7             C.1.7 - Marital status
# 8  C.1.8 - Citizenship (nationality)
# 9      C.1.9 - Communcation language
#
#                                           definition             type card.  \
# 0  C.1 - EHDS refined base model for Patient/subj...              NaN  0..*
# 1  An identifier of the patient that is unique wi...       Identifier  1..*
# 2  Name associated with the patient/subject. Name...    EHDSHumanName  0..*
# 3  The date of birth of the patient [ISO TS 22220...         dateTime  0..1
# 4  This field must contain a recognized valid val...  CodeableConcept  0..1
# 5  Mailing and home or office addresses. The addr...      EHDSAddress  0..*
# 6  Telecommunication contact information (address...      EHDSTelecom  0..*
# 7                Marital (civil) status of a patient  CodeableConcept  0..1
# 8            Citizenship/nationality of the patient.  CodeableConcept  0..*
# 9  The language which can be used to communicate ...  CodeableConcept  0..*
#
#                                              binding
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'strength': 'preferred', 'description': 'HL7 ...
# 5                                                NaN
# 6                                                NaN
# 7  {'strength': 'preferred', 'description': 'HL7 ...
# 8  {'strength': 'preferred', 'description': 'ISO ...
# 9  {'strength': 'preferred', 'description': 'BCP ...

# %%
mapbase = 'maps'
maps = os.path.join(mapbase, 'xtehr2zibs')
os.listdir(maps)
# Out:
# ['Patient-full.xlsx',
#  'Patient.xlsx',
#  'Procedure-comments.md',
#  'Procedure-full.xlsx',
#  'Procedure.csv',
#  'Procedure.md',
#  'Procedure.xlsx',
#  '~$Patient.xlsx']

# %%
file = 'Patient'
mappath = os.path.join(maps, file + '.xlsx')
mapdf = pd.read_excel(mappath)
mapdf
# Out:
#                                 xtehr                                  zib
# 0                         EHDSPatient                              Patient
# 1      EHDSPatient.personalIdentifier  Patient.PatientIdentificationNumber
# 2                    EHDSPatient.name              Patient.NameInformation
# 3             EHDSPatient.dateOfBirth                  Patient.DateOfBirth
# 4    EHDSPatient.administrativeGender                       Patient.Gender
# 5                 EHDSPatient.address           Patient.AddressInformation
# 6                 EHDSPatient.telecom                                  NaN
# 7           EHDSPatient.maritalStatus                                  NaN
# 8             EHDSPatient.citizenship                                  NaN
# 9   EHDSPatient.communicationLanguage                                  NaN
# 10                                NaN           Patient.ContactInformation
# 11                                NaN       Patient.MultipleBirthIndicator
# 12                                NaN               Patient.DeathIndicator
# 13                                NaN                  Patient.DateOfDeath

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                 xtehr                                  zib  \
# 0                         EHDSPatient                              Patient
# 1                 EHDSPatient.address           Patient.AddressInformation
# 2    EHDSPatient.administrativeGender                       Patient.Gender
# 3             EHDSPatient.citizenship                                  NaN
# 4   EHDSPatient.communicationLanguage                                  NaN
# 5             EHDSPatient.dateOfBirth                  Patient.DateOfBirth
# 6           EHDSPatient.maritalStatus                                  NaN
# 7                    EHDSPatient.name              Patient.NameInformation
# 8      EHDSPatient.personalIdentifier  Patient.PatientIdentificationNumber
# 9                 EHDSPatient.telecom                                  NaN
# 10                                NaN           Patient.ContactInformation
# 11                                NaN                  Patient.DateOfDeath
# 12                                NaN               Patient.DeathIndicator
# 13                                NaN       Patient.MultipleBirthIndicator
#
#                        name_zib                             path_zib  \
# 0                       Patient                              Patient
# 1            AddressInformation           Patient.AddressInformation
# 2                        Gender                       Patient.Gender
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
# 5                   DateOfBirth                  Patient.DateOfBirth
# 6                           NaN                                  NaN
# 7               NameInformation              Patient.NameInformation
# 8   PatientIdentificationNumber  Patient.PatientIdentificationNumber
# 9                           NaN                                  NaN
# 10           ContactInformation           Patient.ContactInformation
# 11                  DateOfDeath                  Patient.DateOfDeath
# 12               DeathIndicator               Patient.DeathIndicator
# 13       MultipleBirthIndicator       Patient.MultipleBirthIndicator
#
#                    alias_zib type_zib card._zib  stereotype_zib        id_zib  \
# 0                NL: Patient      NaN       NaN     rootconcept   NL-CM:0.1.1
# 1          NL: Adresgegevens      NaN      0..*  data,reference   NL-CM:0.1.4
# 2               NL: Geslacht       CD      0..1            data   NL-CM:0.1.9
# 3                        NaN      NaN       NaN             NaN           NaN
# 4                        NaN      NaN       NaN             NaN           NaN
# 5          NL: Geboortedatum       TS      0..1            data  NL-CM:0.1.10
# 6                        NaN      NaN       NaN             NaN           NaN
# 7           NL: Naamgegevens      NaN      0..1  data,reference   NL-CM:0.1.6
# 8    NL: Identificatienummer       II      0..*            data   NL-CM:0.1.7
# 9                        NaN      NaN       NaN             NaN           NaN
# 10       NL: Contactgegevens      NaN      0..1  data,reference   NL-CM:0.1.5
# 11       NL: DatumOverlijden       TS      0..1            data  NL-CM:0.1.33
# 12  NL: OverlijdensIndicator       BL      0..1            data  NL-CM:0.1.32
# 13     NL: MeerlingIndicator       BL      0..1            data  NL-CM:0.1.31
#
#                                        definition_zib  \
# 0   Root concept of the Patient information model....
# 1                      Patient's address information.
# 2                    Patient’s administrative gender.
# 3                                                 NaN
# 4                                                 NaN
# 5   Patient’s date of birth. The date of birth is ...
# 6                                                 NaN
# 7                                Patient's full name.
# 8   The patient’s identification number. In transf...
# 9                                                 NaN
# 10  Patient’s telephone number(s) or e-mail addres...
# 11  The date on which the patient died. A ‘vague’ ...
# 12  An indication stating whether the patient has ...
# 13  An indication stating whether the patient is o...
#
#                      definitioncode_zib                           id_xtehr  \
# 0          SNOMED CT: 116154003 Patient                        EHDSPatient
# 1                                   NaN                EHDSPatient.address
# 2                    LOINC: 46098-0 Sex   EHDSPatient.administrativeGender
# 3                                   NaN            EHDSPatient.citizenship
# 4                                   NaN  EHDSPatient.communicationLanguage
# 5             LOINC: 21112-8 Birth date            EHDSPatient.dateOfBirth
# 6                                   NaN          EHDSPatient.maritalStatus
# 7                                   NaN                   EHDSPatient.name
# 8                                   NaN     EHDSPatient.personalIdentifier
# 9                                   NaN                EHDSPatient.telecom
# 10                                  NaN                                NaN
# 11  LOINC: 81954-0 Date of death [Date]                                NaN
# 12    SNOMED CT: 397709008 Patient died                                NaN
# 13                                  NaN                                NaN
#
#                            path_xtehr                        short_xtehr  \
# 0                         EHDSPatient                      Patient model
# 1                 EHDSPatient.address                    C.1.5 - Address
# 2    EHDSPatient.administrativeGender      C.1.4 - Administrative gender
# 3             EHDSPatient.citizenship  C.1.8 - Citizenship (nationality)
# 4   EHDSPatient.communicationLanguage      C.1.9 - Communcation language
# 5             EHDSPatient.dateOfBirth              C.1.3 - Date of birth
# 6           EHDSPatient.maritalStatus             C.1.7 - Marital status
# 7                    EHDSPatient.name                       C.1.2 - Name
# 8      EHDSPatient.personalIdentifier        C.1.1 - Personal identifier
# 9                 EHDSPatient.telecom                    C.1.6 - Telecom
# 10                                NaN                                NaN
# 11                                NaN                                NaN
# 12                                NaN                                NaN
# 13                                NaN                                NaN
#
#                                      definition_xtehr       type_xtehr  \
# 0   C.1 - EHDS refined base model for Patient/subj...              NaN
# 1   Mailing and home or office addresses. The addr...      EHDSAddress
# 2   This field must contain a recognized valid val...  CodeableConcept
# 3             Citizenship/nationality of the patient.  CodeableConcept
# 4   The language which can be used to communicate ...  CodeableConcept
# 5   The date of birth of the patient [ISO TS 22220...         dateTime
# 6                 Marital (civil) status of a patient  CodeableConcept
# 7   Name associated with the patient/subject. Name...    EHDSHumanName
# 8   An identifier of the patient that is unique wi...       Identifier
# 9   Telecommunication contact information (address...      EHDSTelecom
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..*                                                NaN
# 2         0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 3         0..*  {'strength': 'preferred', 'description': 'ISO ...
# 4         0..*  {'strength': 'preferred', 'description': 'BCP ...
# 5         0..1                                                NaN
# 6         0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 7         0..*                                                NaN
# 8         1..*                                                NaN
# 9         0..*                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                     zib                              xtehr  \
# 0                               Patient                        EHDSPatient
# 1            Patient.AddressInformation                EHDSPatient.address
# 2                        Patient.Gender   EHDSPatient.administrativeGender
# 3                                   NaN            EHDSPatient.citizenship
# 4                                   NaN  EHDSPatient.communicationLanguage
# 5                   Patient.DateOfBirth            EHDSPatient.dateOfBirth
# 6                                   NaN          EHDSPatient.maritalStatus
# 7               Patient.NameInformation                   EHDSPatient.name
# 8   Patient.PatientIdentificationNumber     EHDSPatient.personalIdentifier
# 9                                   NaN                EHDSPatient.telecom
# 10           Patient.ContactInformation                                NaN
# 11                  Patient.DateOfDeath                                NaN
# 12               Patient.DeathIndicator                                NaN
# 13       Patient.MultipleBirthIndicator                                NaN
#
#    type_zib       type_xtehr card._zib card._xtehr
# 0       NaN              NaN       NaN        0..*
# 1       NaN      EHDSAddress      0..*        0..*
# 2        CD  CodeableConcept      0..1        0..1
# 3       NaN  CodeableConcept       NaN        0..*
# 4       NaN  CodeableConcept       NaN        0..*
# 5        TS         dateTime      0..1        0..1
# 6       NaN  CodeableConcept       NaN        0..1
# 7       NaN    EHDSHumanName      0..1        0..*
# 8        II       Identifier      0..*        1..*
# 9       NaN      EHDSTelecom       NaN        0..*
# 10      NaN              NaN      0..1         NaN
# 11       TS              NaN      0..1         NaN
# 12       BL              NaN      0..1         NaN
# 13       BL              NaN      0..1         NaN

# %%
filepath = file + '-full.xlsx'
mappath = os.path.join(maps, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file + '.csv'
mappath = os.path.join(maps, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('').items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    content += "\n### Comments" + "\n\n"
with open(os.path.join(maps, file + '.md'), 'w') as f:
    f.write(content)
Markdown(content)
# Out:
# # Patient
#
# | zib                                 | xtehr                             | type_zib   | type_xtehr      | card._zib   | card._xtehr   |
# |:------------------------------------|:----------------------------------|:-----------|:----------------|:------------|:--------------|
# | Patient                             | EHDSPatient                       |            |                 |             | 0..*          |
# | Patient.AddressInformation          | EHDSPatient.address               |            | EHDSAddress     | 0..*        | 0..*          |
# | Patient.Gender                      | EHDSPatient.administrativeGender  | CD         | CodeableConcept | 0..1        | 0..1          |
# |                                     | EHDSPatient.citizenship           |            | CodeableConcept |             | 0..*          |
# |                                     | EHDSPatient.communicationLanguage |            | CodeableConcept |             | 0..*          |
# | Patient.DateOfBirth                 | EHDSPatient.dateOfBirth           | TS         | dateTime        | 0..1        | 0..1          |
# |                                     | EHDSPatient.maritalStatus         |            | CodeableConcept |             | 0..1          |
# | Patient.NameInformation             | EHDSPatient.name                  |            | EHDSHumanName   | 0..1        | 0..*          |
# | Patient.PatientIdentificationNumber | EHDSPatient.personalIdentifier    | II         | Identifier      | 0..*        | 1..*          |
# |                                     | EHDSPatient.telecom               |            | EHDSTelecom     |             | 0..*          |
# | Patient.ContactInformation          |                                   |            |                 | 0..1        |               |
# | Patient.DateOfDeath                 |                                   | TS         |                 | 0..1        |               |
# | Patient.DeathIndicator              |                                   | BL         |                 | 0..1        |               |
# | Patient.MultipleBirthIndicator      |                                   | BL         |                 | 0..1        |               |
#
#
#
# ## EHDSPatient
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient |
# | zib | Patient |
# | name_zib | Patient |
# | path_zib | Patient |
# | alias_zib | NL: Patient |
# | type_zib |  |
# | card._zib |  |
# | stereotype_zib | rootconcept |
# | id_zib | NL-CM:0.1.1 |
# | definition_zib | Root concept of the Patient information model. This root concept contains all data elements of the Patient information model. |
# | definitioncode_zib | SNOMED CT: 116154003 Patient |
# | id_xtehr | EHDSPatient |
# | path_xtehr | EHDSPatient |
# | short_xtehr | Patient model |
# | definition_xtehr | C.1 - EHDS refined base model for Patient/subject information |
# | type_xtehr |  |
# | card._xtehr | 0..* |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## EHDSPatient.address
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.address |
# | zib | Patient.AddressInformation |
# | name_zib | AddressInformation |
# | path_zib | Patient.AddressInformation |
# | alias_zib | NL: Adresgegevens |
# | type_zib |  |
# | card._zib | 0..* |
# | stereotype_zib | data,reference |
# | id_zib | NL-CM:0.1.4 |
# | definition_zib | Patient's address information. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.address |
# | path_xtehr | EHDSPatient.address |
# | short_xtehr | C.1.5 - Address |
# | definition_xtehr | Mailing and home or office addresses. The addresses are always sequences of address parts (e.g. street address line, country, ZIP code, city) even if postal address formats may vary depending on the country. An address may or may not include a specific use code; if this attribute is not present it is assumed to be the default address useful for any purpose. |
# | type_xtehr | EHDSAddress |
# | card._xtehr | 0..* |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## EHDSPatient.administrativeGender
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.administrativeGender |
# | zib | Patient.Gender |
# | name_zib | Gender |
# | path_zib | Patient.Gender |
# | alias_zib | NL: Geslacht |
# | type_zib | CD |
# | card._zib | 0..1 |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.9 |
# | definition_zib | Patient’s administrative gender. |
# | definitioncode_zib | LOINC: 46098-0 Sex |
# | id_xtehr | EHDSPatient.administrativeGender |
# | path_xtehr | EHDSPatient.administrativeGender |
# | short_xtehr | C.1.4 - Administrative gender |
# | definition_xtehr | This field must contain a recognized valid value for "administrative gender". If different, "physiological gender" should be communicated elsewhere.  |
# | type_xtehr | CodeableConcept |
# | card._xtehr | 0..1 |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 Administrative Gender'} |
#
# ### Comments
#
#
#
# ## EHDSPatient.citizenship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.citizenship |
# | zib |  |
# | name_zib |  |
# | path_zib |  |
# | alias_zib |  |
# | type_zib |  |
# | card._zib |  |
# | stereotype_zib |  |
# | id_zib |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.citizenship |
# | path_xtehr | EHDSPatient.citizenship |
# | short_xtehr | C.1.8 - Citizenship (nationality) |
# | definition_xtehr | Citizenship/nationality of the patient. |
# | type_xtehr | CodeableConcept |
# | card._xtehr | 0..* |
# | binding_xtehr | {'strength': 'preferred', 'description': 'ISO 3166-1-2'} |
#
# ### Comments
#
#
#
# ## EHDSPatient.communicationLanguage
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.communicationLanguage |
# | zib |  |
# | name_zib |  |
# | path_zib |  |
# | alias_zib |  |
# | type_zib |  |
# | card._zib |  |
# | stereotype_zib |  |
# | id_zib |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.communicationLanguage |
# | path_xtehr | EHDSPatient.communicationLanguage |
# | short_xtehr | C.1.9 - Communcation language |
# | definition_xtehr | The language which can be used to communicate with the patient about his or her health. |
# | type_xtehr | CodeableConcept |
# | card._xtehr | 0..* |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
#
# ### Comments
#
#
#
# ## EHDSPatient.dateOfBirth
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.dateOfBirth |
# | zib | Patient.DateOfBirth |
# | name_zib | DateOfBirth |
# | path_zib | Patient.DateOfBirth |
# | alias_zib | NL: Geboortedatum |
# | type_zib | TS |
# | card._zib | 0..1 |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.10 |
# | definition_zib | Patient’s date of birth. The date of birth is mandatory for a patient. A vague date (such as only the year) is permitted. |
# | definitioncode_zib | LOINC: 21112-8 Birth date |
# | id_xtehr | EHDSPatient.dateOfBirth |
# | path_xtehr | EHDSPatient.dateOfBirth |
# | short_xtehr | C.1.3 - Date of birth |
# | definition_xtehr | The date of birth of the patient [ISO TS 22220]. As age of the patient might be important for correct interpretation of the test result values, complete date of birth should be provided. |
# | type_xtehr | dateTime |
# | card._xtehr | 0..1 |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## EHDSPatient.maritalStatus
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.maritalStatus |
# | zib |  |
# | name_zib |  |
# | path_zib |  |
# | alias_zib |  |
# | type_zib |  |
# | card._zib |  |
# | stereotype_zib |  |
# | id_zib |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.maritalStatus |
# | path_xtehr | EHDSPatient.maritalStatus |
# | short_xtehr | C.1.7 - Marital status |
# | definition_xtehr | Marital (civil) status of a patient |
# | type_xtehr | CodeableConcept |
# | card._xtehr | 0..1 |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 marital-status'} |
#
# ### Comments
#
#
#
# ## EHDSPatient.name
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.name |
# | zib | Patient.NameInformation |
# | name_zib | NameInformation |
# | path_zib | Patient.NameInformation |
# | alias_zib | NL: Naamgegevens |
# | type_zib |  |
# | card._zib | 0..1 |
# | stereotype_zib | data,reference |
# | id_zib | NL-CM:0.1.6 |
# | definition_zib | Patient's full name. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.name |
# | path_xtehr | EHDSPatient.name |
# | short_xtehr | C.1.2 - Name |
# | definition_xtehr | Name associated with the patient/subject. Name might consist of name parts, e.g. Given name or names, family name/surname, name prefix etc. |
# | type_xtehr | EHDSHumanName |
# | card._xtehr | 0..* |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## EHDSPatient.personalIdentifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.personalIdentifier |
# | zib | Patient.PatientIdentificationNumber |
# | name_zib | PatientIdentificationNumber |
# | path_zib | Patient.PatientIdentificationNumber |
# | alias_zib | NL: Identificatienummer |
# | type_zib | II |
# | card._zib | 0..* |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.7 |
# | definition_zib | The patient’s identification number. In transfer situations, use of the social security number (BSN) must comply with the Use of Social Security Numbers in Healthcare Act (Wbsn-z). In other situations, other number systems can be used, such as internal hospital patient numbers for example. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.personalIdentifier |
# | path_xtehr | EHDSPatient.personalIdentifier |
# | short_xtehr | C.1.1 - Personal identifier |
# | definition_xtehr | An identifier of the patient that is unique within a defined scope. Example: National ID (birth number) or National patient identifier for the Czech patient. Multiple identifiers could be provided.  |
# | type_xtehr | Identifier |
# | card._xtehr | 1..* |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## EHDSPatient.telecom
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSPatient.telecom |
# | zib |  |
# | name_zib |  |
# | path_zib |  |
# | alias_zib |  |
# | type_zib |  |
# | card._zib |  |
# | stereotype_zib |  |
# | id_zib |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSPatient.telecom |
# | path_xtehr | EHDSPatient.telecom |
# | short_xtehr | C.1.6 - Telecom |
# | definition_xtehr | Telecommunication contact information (addresses) associated to a person. Multiple telecommunication addresses might be provided. |
# | type_xtehr | EHDSTelecom |
# | card._xtehr | 0..* |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## zib: Patient.ContactInformation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Patient.ContactInformation |
# | name_zib | ContactInformation |
# | path_zib | Patient.ContactInformation |
# | alias_zib | NL: Contactgegevens |
# | type_zib |  |
# | card._zib | 0..1 |
# | stereotype_zib | data,reference |
# | id_zib | NL-CM:0.1.5 |
# | definition_zib | Patient’s telephone number(s) or e-mail address(es). |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | path_xtehr |  |
# | short_xtehr |  |
# | definition_xtehr |  |
# | type_xtehr |  |
# | card._xtehr |  |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## zib: Patient.DateOfDeath
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Patient.DateOfDeath |
# | name_zib | DateOfDeath |
# | path_zib | Patient.DateOfDeath |
# | alias_zib | NL: DatumOverlijden |
# | type_zib | TS |
# | card._zib | 0..1 |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.33 |
# | definition_zib | The date on which the patient died. A ‘vague’ date, such as only the year, is permitted. |
# | definitioncode_zib | LOINC: 81954-0 Date of death [Date] |
# | id_xtehr |  |
# | path_xtehr |  |
# | short_xtehr |  |
# | definition_xtehr |  |
# | type_xtehr |  |
# | card._xtehr |  |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## zib: Patient.DeathIndicator
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Patient.DeathIndicator |
# | name_zib | DeathIndicator |
# | path_zib | Patient.DeathIndicator |
# | alias_zib | NL: OverlijdensIndicator |
# | type_zib | BL |
# | card._zib | 0..1 |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.32 |
# | definition_zib | An indication stating whether the patient has died. |
# | definitioncode_zib | SNOMED CT: 397709008 Patient died |
# | id_xtehr |  |
# | path_xtehr |  |
# | short_xtehr |  |
# | definition_xtehr |  |
# | type_xtehr |  |
# | card._xtehr |  |
# | binding_xtehr |  |
#
# ### Comments
#
#
#
# ## zib: Patient.MultipleBirthIndicator
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Patient.MultipleBirthIndicator |
# | name_zib | MultipleBirthIndicator |
# | path_zib | Patient.MultipleBirthIndicator |
# | alias_zib | NL: MeerlingIndicator |
# | type_zib | BL |
# | card._zib | 0..1 |
# | stereotype_zib | data |
# | id_zib | NL-CM:0.1.31 |
# | definition_zib | An indication stating whether the patient is of a multiple birth. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | path_xtehr |  |
# | short_xtehr |  |
# | definition_xtehr |  |
# | type_xtehr |  |
# | card._xtehr |  |
# | binding_xtehr |  |
#
# ### Comments
